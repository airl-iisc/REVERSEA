# %%
from transmap import process_images 

process_images(input_dir= "RAW", 
               output_dir= r"Transmap")

# %%
## To train:
# !python3 reversea_uie.py --images "RAW" \
                     --depth "Transmap" \
                     --output "Output" \
                     --checkpoints "Output/check"
# Out:
# Seed: 4521128044779215001
# training
# ...
# 100%|████████████████████████████████████| 500/500 [00:00<00:00, 3956890.57it/s]
# Losses: -0.297729164
# Avg time per eval: 6.450520 ms (6.450515 ms bs, 0.000004 ms at)
# UCIQE: 0.9399103792909957
# UQIMS: 2.8560153053402537
# UCIQE: 0.7549555977488194
# UQIMS: 3.3238572359978615
# UCIQE: 0.7766580263400652
# UQIMS: 3.374191507304479
# UCIQE: 0.5764409934666177
# UQIMS: 3.2989042573013085
# UCIQE: 0.5992475176482654
# UQIMS: 3.1955473253772775
# UCIQE: 0.532662905675849
# UQIMS: 3.1367520070078863
# UCIQE: 0.6393695108466255
# UQIMS: 3.34148799772593
# Evaluation metrics saved to Output/evaluation_metrics.xlsx

# %%
##  INFERENCE
# !python3 inf.py --images "RAW" \
                     --depth "Transmap" \
                     --output 'Out_inf' \
                     --checkpoints 'Output/check'
